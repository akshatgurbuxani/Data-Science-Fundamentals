# %% [markdown]
# ## Lab 02 - Pandas and Data Visualization
# This notebook will introduce you to the basics of Pandas and Data Visualization. You will learn how to load data into a Pandas DataFrame, how to perform basic data analysis, and how to visualize data. The first part of this notebook will be an interactive tutorial, and the second part will be practice exercises for you to do! **Note that the practice problems will be checked when submitted!**

# %% [markdown]
# #### Pandas
# Pandas is a popular open-source Python library that provides data structures and data analysis tools for working with structured data. Pandas is a versatile library that simplifies data manipulation, analysis, and exploration in Python. Some of its uses:
# * Tabular Data Handling
# * Data Cleaning and Transformation
# * Data Exploration
# * Data Import/Export
# * Data Visualization
#
# #### Matplotlib
# Matplotlib is a widely used for creating static, animated, and interactive visualizations. Whether you are conducting data analysis, scientific research, or data communication, Matplotlib helps you present your findings effectively and intuitively.

# %% [markdown]
# ### Pre-requisites

# %%
# In case you don't have pandas, uncomment
# the following lines and run the cell

# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/95/25/4178ff92b6e523c9ad48ed3822b26375d5a5173b28b75ac7c1cb640a9c94/matplotlib-3.8.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading matplotlib-3.8.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/09/fe/086e6847ee53da10ddf0b6c5e5f877ab43e68e355d2f4c85f67561ee8a57/contourpy-1.1.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading contourpy-1.1.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/28/05/a02865cdf7db56238f4e4df933ee765c92b407ac6cc3513763506d0967b7/fonttools-4.42.1-cp39-cp39-macosx_10_9_universal2.whl.metadata
#   Downloading fonttools-4.42.1-cp39-cp39-macosx_10_9_universal2.whl.metadata (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.0/151.0 kB 4.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.0.1 from https://files.pythonhosted.org/packages/89/a8/3b7e14121bea4438b87630557645bb7648b17b54acaa39b93f4bf7f8d33e/kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/akshatgurbuxani/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/akshatgurbuxani/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Obtaining dependency information for pillow>=6.2.0 from https://files.pythonhosted.org/packages/3c/56/8449d670bae6e8f1b45e12cc2746561e42d3d80e3a432bf6f6e71c260aa1/Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akshatgurbuxani/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Obtaining dependency information for importlib-resources>=3.2.0 from https://files.pythonhosted.org/packages/65/6e/09d8816b5cb7a4006ef8ad1717a2703ad9f331dae9717d9f22488a2d6469/importlib_resources-6.1.0-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/akshatgurbuxani/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Downloading matplotlib-3.8.0-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 9.2 MB/s eta 0:00:0000:0100:01m
# Downloading contourpy-1.1.1-cp39-cp39-macosx_11_0_arm64.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 10.7 MB/s eta 0:00:00
# Downloading fonttools-4.42.1-cp39-cp39-macosx_10_9_universal2.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.1 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.8 MB/s eta 0:00:00
# Downloading Pillow-10.0.1-cp39-cp39-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.11.0 fonttools-4.42.1 importlib-resources-6.1.0 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.0.1 pyparsing-3.1.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Overview
# In this notebook, you will be learning how to use the Pandas library by working with the `cookies.csv` file.
#
# #### `cookies.csv` file :
#
# The `cookies.csv` file contains information about cookies that were made in Rico's Bisquito's factory.
#
# The columns are the following:
#
# `cookie`: the name of a cookie
# `ingredients`: a list of the cookie's ingredients
# `calories`: the number of calories the created cookie has
# `radius`: the radius of the created cookie, in cm
# `cost_to_make`: the cost it took to make the created cookie, in dollars

# %% [markdown]
# ### Reading the CSV file
#
# First, we need to import the Pandas library. We will be using the `pd` alias for the Pandas library.

# %%
#TODO: import pandas and matplotlib in this cell

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We will now look at the `cookies.csv` file. We will use the `pd.read_csv()` function to read in the CSV file. We will store the data in a variable called `cookies`.

# %%
#TODO: read the cookies.csv file into a pandas dataframe
df = pd.read_csv('cookies.csv')

# %% [markdown]
# #### Dataframe
# Dataframes are a data structure that Pandas uses to store data. Dataframes are similar to tables in a database. Dataframes have rows and columns. Each row represents a single data point, and each column represents a feature of the data point.

# %% [markdown]
# We will then make sure we imported the data correctly by printing out the first 10 rows of the data, using the `head()` function.

# %%
#TODO: print the head of the dataframe
df.head(10)
# Out:
#             cookie                                        ingredients  \
# 0     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 3  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 4  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 5     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 6      minty miami          ["flour","mint extract","sugar","butter"]
# 7        chocolate       ["flour","chocolate chips","sugar","butter"]
# 8     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 9      minty miami          ["flour","mint extract","sugar","butter"]
#
#    calories  radius  cost_to_make
# 0       170   3.102          0.67
# 1       198   3.780          1.07
# 2       224   4.069          1.04
# 3       198   3.780          1.07
# 4       191   4.148          1.39
# 5       162   3.241          1.15
# 6       204   3.964          0.84
# 7       243   3.684          1.17
# 8       178   3.989           NaN
# 9       184   3.743          0.74

# %% [markdown]
# ### Checking data types
# You can check the data types of each column using the `dtypes` attribute of the DataFrame.

# %%
#TODO: check the data types of the columns
df.dtypes
# Out:
# cookie           object
# ingredients      object
# calories          int64
# radius          float64
# cost_to_make    float64
# dtype: object

# %% [markdown]
# Now, lets use use `info()` function to get more information about the Dataframe

# %%
# TODO: use info() to get information about datatypes and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cookie                 129 non-null    object
#  1   ingredients            129 non-null    object
#  2   calories               129 non-null    int64
#  3   radius                 129 non-null    float64
#  4   cost_to_make           129 non-null    float64
#  5   radius_greater_than_4  129 non-null    bool
# dtypes: bool(1), float64(2), int64(1), object(2)
# memory usage: 5.3+ KB

# %% [markdown]
# ### Cleaning the data
# Now that we have the data, we need to clean it. For example, some `cost_to_make` fields of some created cookies are missing. To resolve this, we can do many things: we can replace the missing data with the mean of the column, or we can get rid of the row entirely if the `cost_to_make` field is not set.

# %%
#TODO: clean the dataframe and 
# print the head again to make sure 
# the changes took effect

df['cost_to_make'].fillna(df.cost_to_make.mean())
# Out:
# 0      1.17
# 1      1.57
# 2      1.54
# 4      1.89
# 5      1.65
#        ...
# 121    1.92
# 122    2.50
# 125    2.11
# 126    1.83
# 127    1.86
# Name: cost_to_make, Length: 118, dtype: float64

# %% [markdown]
# To also make sure we removed null values, we can check the number of null values in each column using the `isnull()` function.

# %%
#TODO: use the isnull method to make sure your data is clean
df.isnull().sum()
# Out:
# cookie          0
# ingredients     0
# calories        0
# radius          0
# cost_to_make    0
# dtype: int64

# %% [markdown]
# Next, lets check for duplicate rows using the `duplicated()` function. Then, remove those rows using `drop_duplicates()` function.

# %%
# TODO: check for duplicate rows
# then delete those rows form df
df.duplicated()
df.drop_duplicates()
# Out:
#               cookie                                        ingredients  \
# 0       laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1    red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2           nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 4                bbb           ["flour","blueberries","sugar","butter"]
# 5       orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# ..               ...                                                ...
# 121        chocolate       ["flour","chocolate chips","sugar","butter"]
# 122     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 125         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 126  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 127              bbb           ["flour","blueberries","sugar","butter"]
#
#      calories  radius  cost_to_make  radius_greater_than_4
# 0         170   3.102          1.17                  False
# 1         198   3.780          1.57                  False
# 2         224   4.069          1.54                   True
# 4         191   4.148          1.89                   True
# 5         162   3.241          1.65                  False
# ..        ...     ...           ...                    ...
# 121       227   4.085          1.92                   True
# 122       170   3.916          2.50                  False
# 125       211   3.915          2.11                  False
# 126       197   3.906          1.83                  False
# 127       199   4.281          1.86                   True
#
# [118 rows x 6 columns]

# %% [markdown]
# ### Parsing the data
# Now that we have the data, we could parse it to get the information we want. For example, we can check what types of cookies were made by using the `unique()` function on the `cookie` column.

# %%
#TODO: see what cookies are in the dataset
df['cookie'].unique()
# Out:
# array(['laddoo lemon', 'red velvet rauw', 'nevadito', 'bad berry bunny',
#        'orange ozuna', 'minty miami', 'chocolate'], dtype=object)

# %% [markdown]
# We can also check the number of cookies made by using the `value_counts()` function on the `cookie` column.

# %%
#TODO: use value_counts() to see how many 
# cookies of each type there are
df['cookie'].value_counts()
# Out:
# cookie
# red velvet rauw    21
# minty miami        21
# orange ozuna       20
# laddoo lemon       17
# nevadito           17
# bad berry bunny    17
# chocolate          16
# Name: count, dtype: int64

# %% [markdown]
# Or maybe we don't like how long the names of the cookies are, so we can shorten them by using the `replace()` function on the `cookie` column.
#
# For example, let's try changing `"bad berry bunny"` to `"bbb"`.

# %%
#TODO: change bad berry bunny data elements to "bbb"
df['cookie'].replace('bad berry bunny', 'bbb')
# Out:
# 0         laddoo lemon
# 1      red velvet rauw
# 2             nevadito
# 4                  bbb
# 5         orange ozuna
#             ...
# 121          chocolate
# 122       laddoo lemon
# 125           nevadito
# 126    red velvet rauw
# 127                bbb
# Name: cookie, Length: 118, dtype: object

# %% [markdown]
# We may even like the original names better, but we may want to get rid of the spaces. For example, we can change `"orange ozuna"` to `"orange_ozuna"`. Here, we will use the `str.replace()` function.

# %%
#TODO: adjust orange ozuna as described
df['cookie'].replace('orange ozunga', 'orange_ozunga')
# Out:
# 0         laddoo lemon
# 1      red velvet rauw
# 2             nevadito
# 3      red velvet rauw
# 4      bad berry bunny
#             ...
# 124        minty miami
# 125           nevadito
# 126    red velvet rauw
# 127    bad berry bunny
# 128          chocolate
# Name: cookie, Length: 129, dtype: object

# %% [markdown]
# We may even just want to keep the first word of the cookie name. For example, we can change `"orange_ozuna"` to `"orange"`.

# %%
#TODO: adjust all cookies so only the first word
# is used as the cookie name

df['cookie'].replace('orange_ozunga', 'orange ozunga')
df['cookie'].str.split(' ').str[0]
# Out:
# 0         laddoo
# 1            red
# 2       nevadito
# 3            red
# 4            bad
#          ...
# 124        minty
# 125     nevadito
# 126          red
# 127          bad
# 128    chocolate
# Name: cookie, Length: 129, dtype: object

# %% [markdown]
# Another thing that may come to mind is that maybe getting flour could cost more money due to inflation, so we have to adjust our `cost_to_make` values. We can do this by using the `apply()` function on the `cost_to_make` column.

# %%
#Don't edit this method
def adjust_cost(cost):
    return cost + 0.5

#TODO: use apply() to adjust the cost_to_make column.

df['cost_to_make'] = df['cost_to_make'].apply(adjust_cost)

print(df)
# Out:
#               cookie                                        ingredients  \
# 0       laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1    red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2           nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 3    red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 4    bad berry bunny           ["flour","blueberries","sugar","butter"]
# ..               ...                                                ...
# 124      minty miami          ["flour","mint extract","sugar","butter"]
# 125         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 126  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 127  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 128        chocolate       ["flour","chocolate chips","sugar","butter"]
#
#      calories  radius  cost_to_make
# 0         170   3.102          1.17
# 1         198   3.780          1.57
# 2         224   4.069          1.54
# 3         198   3.780          1.57
# 4         191   4.148          1.89
# ..        ...     ...           ...
# 124       204   3.964          1.34
# 125       211   3.915          2.11
# 126       197   3.906          1.83
# 127       199   4.281          1.86
# 128       209   3.182          2.03
#
# [129 rows x 5 columns]

# %% [markdown]
# And we can do a lot more things! We will see these concepts be used in the next homework assignment, along with a couple new ones to show you how powerful Pandas is.

# %% [markdown]
# ### More complicated operations: Grouping, Filtering, Aggregating

# %% [markdown]
# Before trying out these complicated operations, lets first sort the sort the df by the radius of the cookies using the `sort_values()` function.

# %%
# TODO: sort the df using sort_values(by='Column', ascending=False)
df.sort_values(by='radius')
df.sort_values(by='radius', ascending=False)
# Out:
#               cookie                                        ingredients  \
# 110  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 30   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 109         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 60      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 49      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# ..               ...                                                ...
# 0       laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 70      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 22   bad berry bunny           ["flour","blueberries","sugar","butter"]
# 32       minty miami          ["flour","mint extract","sugar","butter"]
# 78      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
#
#      calories  radius  cost_to_make
# 110       198   4.930      1.550000
# 30        204   4.667      1.900000
# 109       211   4.619      1.676579
# 60        186   4.573      1.560000
# 49        195   4.562      1.120000
# ..        ...     ...           ...
# 0         170   3.102      1.170000
# 70        164   3.050      1.676579
# 22        184   2.982      2.510000
# 32        178   2.952      1.340000
# 78        166   1.695      1.320000
#
# [129 rows x 5 columns]

# %% [markdown]
# We may also want to group data by certain attributes. This can be done by using `groupby()`. This method takes in a column name, and groups the data by the values in that column. For example, we can group the data by the `cookie` column.

# %%
#TODO: group by cookie type
df.groupby(by=['cookie'], dropna=False).size()
# Out:
#                                                        ingredients  calories  \
# cookie
# bad berry bunny  ["flour","blueberries","sugar","butter"]["flou...      3178
# chocolate        ["flour","chocolate chips","sugar","butter"]["...      3482
# laddoo lemon     ["flour","lemon juice","sugar","ghee"]["flour"...      2979
# minty miami      ["flour","mint extract","sugar","butter"]["flo...      3959
# nevadito         ["flour","chocolate chips","milk","vanilla ext...      3763
# orange ozuna     ["flour","orange juice","sugar","vegetable oil...      3333
# red velvet rauw  ["flour","cocoa powder","butter","red food col...      4190
#
#                  radius  cost_to_make
# cookie
# bad berry bunny  66.487     28.143158
# chocolate        62.937     27.589737
# laddoo lemon     64.296     30.146316
# minty miami      79.002     30.183158
# nevadito         68.231     31.323158
# orange ozuna     69.552     34.086579
# red velvet rauw  84.734     34.806579

# %% [markdown]
# We can also group by multiple columns. For example, we can group the data by the `cookie` and `ingredients` columns.

# %%
#TODO: group by cookie type and ingredients
df.groupby(by='cookie' and 'ingredients', dropna=False).size()
# Out:
#                                                                                                cookie  \
# ingredients
# ["flour","blueberries","sugar","butter"]            bad berry bunnybad berry bunnybad berry bunnyb...
# ["flour","chocolate chips","milk","vanilla extr...  nevaditonevaditonevaditonevaditonevaditonevadi...
# ["flour","chocolate chips","sugar","butter"]        chocolatechocolatechocolatechocolatechocolatec...
# ["flour","cocoa powder","butter","red food colo...  red velvet rauwred velvet rauwred velvet rauwr...
# ["flour","lemon juice","sugar","ghee"]              laddoo lemonladdoo lemonladdoo lemonladdoo lem...
# ["flour","mint extract","sugar","butter"]           minty miamiminty miamiminty miamiminty miamimi...
# ["flour","orange juice","sugar","vegetable oil"]    orange ozunaorange ozunaorange ozunaorange ozu...
#
#                                                     calories  radius  \
# ingredients
# ["flour","blueberries","sugar","butter"]                3178  66.487
# ["flour","chocolate chips","milk","vanilla extr...      3763  68.231
# ["flour","chocolate chips","sugar","butter"]            3482  62.937
# ["flour","cocoa powder","butter","red food colo...      4190  84.734
# ["flour","lemon juice","sugar","ghee"]                  2979  64.296
# ["flour","mint extract","sugar","butter"]               3959  79.002
# ["flour","orange juice","sugar","vegetable oil"]        3333  69.552
#
#                                                     cost_to_make
# ingredients
# ["flour","blueberries","sugar","butter"]               28.143158
# ["flour","chocolate chips","milk","vanilla extr...     31.323158
# ["flour","chocolate chips","sugar","butter"]           27.589737
# ["flour","cocoa powder","butter","red food colo...     34.806579
# ["flour","lemon juice","sugar","ghee"]                 30.146316
# ["flour","mint extract","sugar","butter"]              30.183158
# ["flour","orange juice","sugar","vegetable oil"]       34.086579

# %% [markdown]
# We may also want to filter the data. For example, we can filter the data to only show the cookies that have a radius greater than 4.3 cm. We can do this by indexing the DataFrame with a boolean expression.

# %%
#TODO: filter using the boolean expression
df[(df['radius'] > 4.3)]
# Out:
#               cookie                                        ingredients  \
# 29          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 30   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 47       minty miami          ["flour","mint extract","sugar","butter"]
# 49      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 60      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 62         chocolate       ["flour","chocolate chips","sugar","butter"]
# 72   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 76   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 80         chocolate       ["flour","chocolate chips","sugar","butter"]
# 87         chocolate       ["flour","chocolate chips","sugar","butter"]
# 88      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 97   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 100      minty miami          ["flour","mint extract","sugar","butter"]
# 101     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 109         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 110  red velvet rauw  ["flour","cocoa powder","butter","red food col...
#
#      calories  radius  cost_to_make
# 29        219   4.346      1.680000
# 30        204   4.667      1.900000
# 47        174   4.388      1.140000
# 49        195   4.562      1.120000
# 60        186   4.573      1.560000
# 62        206   4.328      1.840000
# 72        196   4.425      1.370000
# 76        206   4.319      1.740000
# 80        197   4.461      2.170000
# 87        199   4.474      1.640000
# 88        167   4.401      1.740000
# 97        191   4.475      1.740000
# 100       185   4.307      1.676579
# 101       178   4.519      1.910000
# 109       211   4.619      1.676579
# 110       198   4.930      1.550000

# %% [markdown]
# We may even want to use `groupby()` and filter idea together! For example, we can filter the data to only show the cookies that have a radius greater than 4.3 cm, and group the data by the `cookie` column.

# %%
#TODO: filter the data using the boolean expression
# then group by cookie column
df[(df['radius'] > 4.3)].groupby(by ='cookie', dropna=False).size()
# Out:
#                                                        ingredients  calories  \
# cookie
# chocolate        ["flour","chocolate chips","sugar","butter"]["...       602
# laddoo lemon     ["flour","lemon juice","sugar","ghee"]["flour"...       540
# minty miami      ["flour","mint extract","sugar","butter"]["flo...       359
# nevadito         ["flour","chocolate chips","milk","vanilla ext...       430
# orange ozuna      ["flour","orange juice","sugar","vegetable oil"]       186
# red velvet rauw  ["flour","cocoa powder","butter","red food col...       995
#
#                  radius  cost_to_make
# cookie
# chocolate        13.263      5.650000
# laddoo lemon     13.482      4.770000
# minty miami       8.695      2.816579
# nevadito          8.965      3.356579
# orange ozuna      4.573      1.560000
# red velvet rauw  22.816      8.300000

# %% [markdown]
# We may also want to aggregate the data. For example, we can aggregate the data by looking at the ratio of calories to radius. We can do this by using indexing and the `apply()` function.

# %%
#TODO: add a column to the dataframe that is the
# calories per radius

df['calories_per_radius'] = df.apply(lambda row: row['calories'] / row['radius'], axis = 1)

df.head()
# Out:
#             cookie                                        ingredients  \
# 0     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 4              bbb           ["flour","blueberries","sugar","butter"]
# 5     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
#
#    calories  radius  cost_to_make  radius_greater_than_4  calories_per_radius
# 0       170   3.102          1.17                  False            54.803353
# 1       198   3.780          1.57                  False            52.380952
# 2       224   4.069          1.54                   True            55.050381
# 4       191   4.148          1.89                   True            46.046287
# 5       162   3.241          1.65                  False            49.984573

# %% [markdown]
# Or we can just get rid of this column if we find it useless. We can do this by using the `drop()` function or indexing.

# %%
#TODO: drop the created column
df.drop(columns=['cookie'])
# Out:
#                                            ingredients  calories  radius  \
# 0               ["flour","lemon juice","sugar","ghee"]       170   3.102
# 1    ["flour","cocoa powder","butter","red food col...       198   3.780
# 2    ["flour","chocolate chips","milk","vanilla ext...       224   4.069
# 3    ["flour","cocoa powder","butter","red food col...       198   3.780
# 4             ["flour","blueberries","sugar","butter"]       191   4.148
# ..                                                 ...       ...     ...
# 124          ["flour","mint extract","sugar","butter"]       204   3.964
# 125  ["flour","chocolate chips","milk","vanilla ext...       211   3.915
# 126  ["flour","cocoa powder","butter","red food col...       197   3.906
# 127           ["flour","blueberries","sugar","butter"]       199   4.281
# 128       ["flour","chocolate chips","sugar","butter"]       209   3.182
#
#      cost_to_make
# 0            1.17
# 1            1.57
# 2            1.54
# 3            1.57
# 4            1.89
# ..            ...
# 124          1.34
# 125          2.11
# 126          1.83
# 127          1.86
# 128          2.03
#
# [129 rows x 4 columns]

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# We can also visualize the data. For example, we can visualize the data by plotting the radius of the cookies against the cost to make the cookies. We can do this by using the `plot()` function.

# %%
#TODO: plot the radius (x) versus cost to make (y)
plt.plot(df['radius'], df['cost_to_make'])

# %% [markdown]
# We may even want to get more specific and visualize the shape of a distribution of the `laddoo lemon`'s radius by making a boxplot. We can also do this by using the `plot()` function.

# %%
#TODO: add the described boxplot
# remember that you changed the name from laddoo lemon to laddoo
plt.boxplot(df.loc[df['cookie'] == 'laddoo lemon', 'radius'])
plt.show()

# %% [markdown]
# Alternatively, we can create a histogram to visualize the distribution of the `laddoo lemon`'s radius. We can also do this by using the `plot()` function.

# %%
#TODO: add the described histogram
plt.hist(df.loc[df['cookie'] == 'laddoo lemon', 'radius'])
plt.show()
df.loc[((df['cookie'] == 'laddoo lemon') & (df['cookie'] == 'bbb')), 'radius']
# Out:
# Series([], Name: radius, dtype: float64)

# %% [markdown]
# Things can get more complicated too. Maybe we want to analyze the behaviors of `bad berry bunny` and `laddoo lemon`'s radius using a boxplot. But this time, let's try it using the alternative `boxplot()` function. For practice, try doing it with `plot()` too!

# %%
#TODO: analyze the two cookie's radius in a boxplot
plt.boxplot(df.loc[((df['cookie'] == 'laddoo lemon') | (df['cookie'] == 'bbb')), 'radius'])
plt.show()

# %% [markdown]
# ### Practice Problems
# Now that you have learned some of Pandas' capabilities, let's try some practice problems! **This is the part that will be checked when you submit it!**

# %% [markdown]
# #### Problem 1
# How many cookies were made? (Hint: use the `shape` attribute)

# %%
#Add your code here
df = pd.read_csv('cookies.csv') # Incase if the contents are changed above
df["cost_to_make"].fillna(df["cost_to_make"].mean(), inplace = True)


df.shape[0]
# Out:
# 129

# %% [markdown]
# #### Problem 2
# Add a column to the DataFrame that has the value `True` if the cookie has a radius greater than 4 cm, and `False` otherwise. (Hint: use the `apply()` function)

# %%
#Add your code here
df['radius_greater_than_4'] = df['radius'] > 4
df
# Out:
#               cookie                                        ingredients  \
# 0       laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1    red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2           nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 3    red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 4    bad berry bunny           ["flour","blueberries","sugar","butter"]
# ..               ...                                                ...
# 124      minty miami          ["flour","mint extract","sugar","butter"]
# 125         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 126  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 127  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 128        chocolate       ["flour","chocolate chips","sugar","butter"]
#
#      calories  radius  cost_to_make  average_radius  radius_greater_than_4
# 0         170   3.102          0.67        3.782118                  False
# 1         198   3.780          1.07        4.034952                  False
# 2         224   4.069          1.04        4.013588                   True
# 3         198   3.780          1.07        4.034952                  False
# 4         191   4.148          1.39        3.911000                   True
# ..        ...     ...           ...             ...                    ...
# 124       204   3.964          0.84        3.762000                  False
# 125       211   3.915          1.61        4.013588                  False
# 126       197   3.906          1.33        4.034952                  False
# 127       199   4.281          1.36        3.911000                   True
# 128       209   3.182          1.53        3.933562                  False
#
# [129 rows x 7 columns]

# %% [markdown]
# #### Problem 3
#
# Group the data by the `cookie` column, and find the average radius of each cookie. (Hint: use the `groupby()` and `transform()` function). Add this column to the DataFrame.

# %%
#Add your code here
df['average_radius'] = df.groupby('cookie')['radius'].transform('mean')
df.head()
# Out:
#        cookie                                        ingredients  calories  \
# 2    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 7   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 10   nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 17  chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 19   nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
#
#     radius  cost_to_make  average_radius
# 2    4.069          1.04        4.013588
# 7    3.684          1.17        3.933562
# 10   3.848          1.28        4.013588
# 17   3.182          1.53        3.933562
# 19   4.043          1.29        4.013588

# %% [markdown]
# #### Problem 4
# Create a new DataFrame that only contains the cookies that have the ingredient `"chocolate chips"`. (Hint: use the `str.contains()` function)

# %%
#Add your code here
df_chocolate_chips = df[(df['ingredients'].str.contains('chocolate chips'))]
df_chocolate_chips.head()
# Out:
#        cookie                                        ingredients  calories  \
# 2    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 7   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 10   nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 17  chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 19   nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
#
#     radius  cost_to_make  average_radius  radius_greater_than_4
# 2    4.069          1.04        4.013588                   True
# 7    3.684          1.17        3.933562                  False
# 10   3.848          1.28        4.013588                  False
# 17   3.182          1.53        3.933562                  False
# 19   4.043          1.29        4.013588                   True

# %% [markdown]
# #### Problem 5
#
# Create a boxplot of `cost_to_make` for all cookies except `chocolate` using the `boxplot()` function.

# %%
#Add your code here
plt.boxplot(df.loc[(df['cookie'] == 'chocolate'), "cost_to_make"].values)
plt.show()

# %% [markdown]
# #### Problem 6
#
# Create a histogram of the `bad berry bunny`'s calories using the `plot()` function.

# %%
#Add your code here
plt.hist(df.loc[(df['cookie'] == 'bad berry bunny'), "calories"].values)
plt.show()

# %% [markdown]
# #### Problem 7
#
# Calculate the average calories per cookie type and display the result in a bar chart.

# %%
#Add your code here
df.groupby('cookie')['calories'].agg('mean').plot.bar()
# Out:
# <Axes: xlabel='cookie'>

# %% [markdown]
# #### Problem 8
#
# Find the top 3 most expensive cookies in terms of cost_to_make

# %%
#Add your code here

df.sort_values(by = 'cost_to_make', ascending = False).reset_index(drop = True).head(3)
# Out:
#          cookie                                        ingredients  calories  \
# 0  laddoo lemon             ["flour","lemon juice","sugar","ghee"]       176
# 1      nevadito  ["flour","chocolate chips","milk","vanilla ext...       220
# 2  orange ozuna   ["flour","orange juice","sugar","vegetable oil"]       159
#
#    radius  cost_to_make  average_radius  radius_greater_than_4
# 0   4.110          2.27        3.782118                   True
# 1   3.855          2.21        4.013588                  False
# 2   3.429          2.09        3.477600                  False
